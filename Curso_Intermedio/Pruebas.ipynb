# %% [markdown]
# # Pruebas sobre el código del proyecto

# %%
# Nos traemos el codigo del proyecto pasado
from Pym import tools

# 1. Crear la base de datos del proyecto
tools.definiciones()
# Out:
# Base de datos creada/conectada
# Tabla creada

# %%
# 2. Crear la infomacion e insertar en la base de datos
tools.proceso('2025-05-03')
# Out:
# Comienzo del programa .....
# Generación exitosa al 2025-05-03
# Comienzo de las inserciones ....
# Inserción existosa
# Fecha: 2025-05-03 || Tiempo de ejecución: 0.05 minutos

# %%
# Consultamos la base de datos
import sqlite3 as sql
import pandas as pd

query = "SELECT * FROM VENTAS_2025"
con = sql.connect('Ventas.db')
df = pd.read_sql_query(query, con)
con.close()

df
# Out:
#           Fecha  Sucursal    Producto Clave_Producto   Precio  \
# 0    2025-05-03    Centro      Cables        WQA-959    13.76
# 1    2025-05-03    Zócalo     Laptops        SPT-793  4830.98
# 2    2025-05-03     Coapa  Borradores        VRX-179  2859.11
# 3    2025-05-03  Cuemanco    Pinturas        OET-741   664.03
# 4    2025-05-03    Centro   Uniformes        XCE-563   379.84
# ..          ...       ...         ...            ...      ...
# 995  2025-05-03    Centro     Laptops        UZM-686  1051.38
# 996  2025-05-03  Cuemanco    Mochilas        UYH-596  1839.21
# 997  2025-05-03     Coapa    Libretas        OLS-754  2166.99
# 998  2025-05-03  Cuemanco  Borradores        XQN-331   436.55
# 999  2025-05-03  Cuemanco  Cargadores        HJJ-878   751.56
#
#      Cantidad_Vendida  Total_Ticket
# 0                 436       5999.36
# 1                 693    3347869.14
# 2                 804    2298724.44
# 3                 375     249011.25
# ...
